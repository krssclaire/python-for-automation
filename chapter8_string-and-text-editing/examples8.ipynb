# %% [markdown]
# # Chapter 8 - String and Text editing

# %% [markdown]
# ## Examples

# %%
spam = 'Say hi to Bob\'s mother.'
spam
# Out:
# "Say hi to Bob's mother."

# %%
print("Hello there!\nHow are you?\nI\'m doing fine.")
# Out:
# Hello there!
# How are you?
# I'm doing fine.

# %%
print(r'The file is in C:\Users\Alice\Desktop')
# Out:
# The file is in C:\Users\Alice\Desktop

# %%
print('Hello...\n\n...world!')  # Without a raw string
# Out:
# Hello...
#
# ...world!

# %%
print('''
Dear Alice,

Can you feed Eve's cat this weekend?

Sincerely,
Bob
''')
# Out:
# Dear Alice,
#
# Can you feed Eve's cat this weekend?
#
# Sincerely,
# Bob

# %%
greeting = 'Hello, world!'
print(greeting[0])
print(greeting [4])
print(greeting[-1])
print(greeting[0:5])
print(greeting[:5])
print(greeting[7:-1])
print(greeting[7:])
# Out:
# H
# o
# !
# Hello
# Hello
# world
# world!

# %%
('Hello' in 'Hello, World')
print('Hello' in 'Hello')
print('HELLO' in 'Hello, World')
print('' in 'spam')
print('cats' not in 'cats and dogs')
# Out:
# True
# False
# True
# False

# %%
name = 'Al'
age = 4000
f'My name is {name}. I am {age} years old.'
# Out:
# 'My name is Al. I am 4000 years old.'

# %%
name = 'Al'
age = 4000
print('My name is %s. I am %s years old.' % (name, age))
'In ten years I will be %s' % (age + 10)
# Out:
# My name is Al. I am 4000 years old.
# 'In ten years I will be 4010'

# %%
print('My name is {}. I am {} years old.'.format(name, age))
# Out:
# My name is Al. I am 4000 years old.

# %%
print('hello'.isalpha())
print('hello123'.isalpha())
print('hello123'.isalnum())
print('hello'.isalnum())
print('123'.isdecimal())
print('    '.isspace())
print('This Is Title Case'.istitle())
# Out:
# True
# False
# True
# True
# True
# True
# True

# %%
print('Hello, world!'.startswith('Hello'))
print('Hello, world!'.endswith('world!'))
print('abc123'.startswith('abcdef'))
print('abc123'.endswith('12'))
print('Hello, world!'.startswith('Hello, world!'))
print('Hello, world!'.endswith('Hello, world!'))
# Out:
# True
# True
# False
# False
# True
# True

# %%
print(', '.join(['cats', 'rats', 'bats']))
print(' '.join(['My', 'name', 'is', 'Simon']))
print('ABC'.join(['My', 'name', 'is', 'Simon']))
# Out:
# cats, rats, bats
# My name is Simon
# MyABCnameABCisABCSimon

# %%
print('My name is Simon'.split())
print('My name is Simon'.split('m'))
# Out:
# ['My', 'name', 'is', 'Simon']
# ['My na', 'e is Si', 'on']

# %%
spam = '''Dear Alice,
There is a milk bottle in the fridge
that is labeled "Milk Experiment."
Please do not drink it.
Sincerely,
Bob'''
spam.split('\n')
# Out:
# ['Dear Alice,',
#  'There is a milk bottle in the fridge',
#  'that is labeled "Milk Experiment."',
#  'Please do not drink it.',
#  'Sincerely,',
#  'Bob']

# %%
print('Hello'.rjust(10))
print('Hello'.rjust(20))
print('Hello, World'.rjust(20))
print('Hello'.ljust(10, '*'))
# Out:
#      Hello
#                Hello
#         Hello, World
# Hello*****

# %%
spam = '    Hello, World    '
print(spam.strip())
print(spam.lstrip())
print(spam.rstrip())
# Out:
# Hello, World
# Hello, World
#     Hello, World

# %%
spam = 'SpamSpamBaconSpamEggsSpamSpam'
spam.strip('ampS')
# Out:
# 'BaconSpamEggs'

# %%
print(ord('A'))
print(ord('4'))
print(ord('!'))
print(chr(65))
# Out:
# 65
# 52
# 33
# A

# %% [markdown]
# #### Pyperclip - copy ad paste strings

# %%
import pyperclip
pyperclip.copy('Hello, world!')
pyperclip.paste()

# %% [markdown]
# ## Practice Questions

# %%
print('Remember, remember, the fifth of November.'.rjust(50, '-'))
print('Remember, remember, the fifth of November.'.ljust(50, '-'))
print('Remember, remember, the fifth of November.'.center(50, '-'))
print('      Remember, remember, the fifth of November.    '.strip(' '))
#''.join('There can be only one.'.split())
# Out:
# --------Remember, remember, the fifth of November.
# Remember, remember, the fifth of November.--------
# ----Remember, remember, the fifth of November.----
# Remember, remember, the fifth of November.
